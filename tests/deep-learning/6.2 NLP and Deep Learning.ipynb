# %% [markdown]
# # Natural Language Processing using Artificial Neural Networks

# %% [markdown]
# > “In God we trust. All others must bring data.” – W. Edwards Deming, statistician

# %% [markdown]
# # Word Embeddings
#
# ### What?
# Convert words to vectors in a high dimensional space. Each dimension denotes an aspect like gender, type of object / word.
#
# "Word embeddings" are a family of natural language processing techniques aiming at mapping semantic meaning into a geometric space. This is done by associating a numeric vector to every word in a dictionary, such that the distance (e.g. L2 distance or more commonly cosine distance) between any two vectors would capture part of the semantic relationship between the two associated words. The geometric space formed by these vectors is called an embedding space.

# %% [markdown]
# ### Why?
# By converting words to vectors we build relations between words. More similar the words in a dimension, more closer their scores are.
#
# ### Example
# _W(green) = (1.2, 0.98, 0.05, ...)_
#
# _W(red) = (1.1, 0.2, 0.5, ...)_
#
# Here the vector values of _green_ and _red_ are very similar in one dimension because they both are colours. The value for second dimension is very different because red might be depicting something negative in the training data while green is used for positiveness.
#
# By vectorizing we are indirectly building different kind of relations between words.

# %% [markdown]
# ## Example of `word2vec` using gensim

# %%
from gensim.models import word2vec
from gensim.models.word2vec import Word2Vec

# %% [markdown]
# ### Reading blog post from data directory

# %%
import os
import pickle

# %%
DATA_DIRECTORY = os.path.join(os.path.abspath(os.path.curdir), '..', 
                              'data', 'word_embeddings')

# %%
male_posts = []
female_post = []

# %%
with open(os.path.join(DATA_DIRECTORY,"male_blog_list.txt"),"rb") as male_file:
    male_posts= pickle.load(male_file)
    
with open(os.path.join(DATA_DIRECTORY,"female_blog_list.txt"),"rb") as female_file:
    female_posts = pickle.load(female_file)

# %%
print(len(female_posts))
print(len(male_posts))
# Out:
# 2252
# 2611

# %%
filtered_male_posts = list(filter(lambda p: len(p) > 0, male_posts))
filtered_female_posts = list(filter(lambda p: len(p) > 0, female_posts))
posts = filtered_female_posts + filtered_male_posts

# %%
print(len(filtered_female_posts), len(filtered_male_posts), len(posts))
# Out:
# 2247 2595 4842

# %% [markdown]
# ## Word2Vec

# %%
w2v = Word2Vec(size=200, min_count=1)
w2v.build_vocab(map(lambda x: x.split(), posts[:100]), )

# %%
w2v.wv.vocab
# Out:
# {'Well,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe48d0>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe4da0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe4eb8>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe52e8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5390>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5470>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5668>,
#  'morning.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe56d8>,
#  "It's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5780>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5978>,
#  'raining,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5cc0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe5e80>,
#  "that's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe6358>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe6c88>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd82e8>,
#  'me.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8518>,
#  'Sort': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8588>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd85f8>,
#  'suits': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8668>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8710>,
#  'mood.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8860>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd88d0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8908>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd89b0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8c88>,
#  'stayed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8d30>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd8dd8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde128>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde160>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde358>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde518>,
#  'cats.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde588>,
#  'This': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde7b8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde7f0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde908>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fde9b0>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdea20>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdea90>,
#  'though!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdeac8>,
#  'People': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdeb38>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdec88>,
#  'basements,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdee10>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdee80>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdeef0>,
#  'lakes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdef28>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdef60>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdefd0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1b70>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1128>,
#  'courses': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1198>,
#  'fields,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1240>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1278>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe12b0>,
#  'green,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe12e8>,
#  'green.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1358>,
#  'But,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1400>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1438>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe14e0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1518>,
#  '26': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1550>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe15c0>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1630>,
#  'Friday,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe16a0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1780>,
#  "we'll": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe17b8>,
#  'dealing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1860>,
#  'mosquitos': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1898>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1be0>,
#  'week.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1cc0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1cf8>,
#  'Winnipeg': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1da0>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1dd8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1eb8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1f28>,
#  '"Old': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe1f60>,
#  'Testament"': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf048>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf080>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf0b8>,
#  'urlLink': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf0f0>,
#  'CBC': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf390>,
#  'Radio': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf3c8>,
#  'One': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf438>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf4a8>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf630>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf668>,
#  'rings': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf6a0>,
#  'true.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf748>,
#  'Floods,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf978>,
#  'infestations,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdf9e8>,
#  'etc.,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfbe0>,
#  'etc..': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfcf8>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfd30>,
#  'four-year': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfd68>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfda0>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfdd8>,
#  'stops': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdfef0>,
#  'talking.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0d68>,
#  "She'll": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0e48>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0f98>,
#  '"Mom?"': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0128>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0198>,
#  '"Yes?",': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0358>,
#  "she'll": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0390>,
#  '"Ummm....': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe03c8>,
#  'ummm...': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0438>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0470>,
#  'yeah.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0588>,
#  'Where': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe05c0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe07b8>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0828>,
#  'bugs': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0898>,
#  'hide': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe0a58>,
#  'rain?"': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe28d0>,
#  'Anything': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2908>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2c50>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2c88>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2cc0>,
#  'voice.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2d30>,
#  'Very,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2e48>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2ef0>,
#  'exhausting.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2f60>,
#  'Now': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2780>,
#  'remember!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe20b8>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2128>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe21d0>,
#  'work!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe22e8>,
#  '*Sigh*': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe26d8>,
#  'Actually': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2710>,
#  "it's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe2748>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8080>,
#  'raining': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe80f0>,
#  'yet,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8160>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe81d0>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8208>,
#  'tickets': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8240>,
#  'Goldeyes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8278>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe82e8>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8358>,
#  "Mom's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe83c8>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe84a8>,
#  'tonight,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe84e0>,
#  'rain.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8518>,
#  'Do': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8550>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe86a0>,
#  'cancel': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe87b8>,
#  'baseball': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe87f0>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8828>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8898>,
#  'rain?': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe88d0>,
#  'Although': <gensim.models.keyedvectors.Vocab at 0x7f1aa22f1828>,
#  'ballpark': <gensim.models.keyedvectors.Vocab at 0x7f1aaa533208>,
#  'beautiful,': <gensim.models.keyedvectors.Vocab at 0x7f1ad84f0550>,
#  "ain't": <gensim.models.keyedvectors.Vocab at 0x7f1ad84f0d68>,
#  'SkyDome': <gensim.models.keyedvectors.Vocab at 0x7f1aa25595f8>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f1adf5bdb38>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x7f1adf5bdd68>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084160>,
#  'Jays': <gensim.models.keyedvectors.Vocab at 0x7f1aa20840f0>,
#  'occassionally': <gensim.models.keyedvectors.Vocab at 0x7f1aa20840b8>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f1aa20841d0>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084128>,
#  'Toronto': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084198>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084080>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084470>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7f1aa20844e0>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084588>,
#  'now.': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084518>,
#  "don't": <gensim.models.keyedvectors.Vocab at 0x7f1aa2084550>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f1aa20844a8>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084208>,
#  'Blue': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084438>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084240>,
#  'now,': <gensim.models.keyedvectors.Vocab at 0x7f1aa20842b0>,
#  "I'm": <gensim.models.keyedvectors.Vocab at 0x7f1aa2084390>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f1aa20843c8>,
#  'cheaper': <gensim.models.keyedvectors.Vocab at 0x7f1aa20842e8>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084320>,
#  'Winnipeg.': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084358>,
#  'Oh,': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084400>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f1aa2084278>,
#  'checked': <gensim.models.keyedvectors.Vocab at 0x7f1ad8472a58>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7f1ad84729e8>,
#  'is!': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433278>,
#  'Ha!': <gensim.models.keyedvectors.Vocab at 0x7f1ad84333c8>,
#  'Just': <gensim.models.keyedvectors.Vocab at 0x7f1ad84332e8>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433630>,
#  'RSS': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433518>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433400>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7f1ad84335f8>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433320>,
#  'easy!': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433390>,
#  'Why': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433470>,
#  "doesn't": <gensim.models.keyedvectors.Vocab at 0x7f1ad8433438>,
#  'it?': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433550>,
#  'Enough': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433240>,
#  'today.': <gensim.models.keyedvectors.Vocab at 0x7f1ad8433358>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x7f1ad84332b0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x7f1ad84334a8>,
#  'shining': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8908>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8978>,
#  'planting': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe89b0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe89e8>,
#  'flowers': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8a20>,
#  '(that': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8a58>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8a90>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8ac8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8b00>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8ba8>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8be0>,
#  'pots)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8c18>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8c88>,
#  'kindergartners': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8cc0>,
#  'preschooler': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8e48>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8e80>,
#  'refusing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8eb8>,
#  'outside.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8f28>,
#  'Little': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8f60>,
#  'gameboy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8f98>,
#  'junkies...': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe8fd0>,
#  'talk!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70048>,
#  'Last': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70080>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f700f0>,
#  'today,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70160>,
#  'promise.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f701d0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70208>,
#  'reminded': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70240>,
#  'me,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f702b0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70320>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70358>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70390>,
#  'canning': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f703c8>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70400>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70438>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70470>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70518>,
#  'Is': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70550>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70588>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f705f8>,
#  'art?': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70630>,
#  'Are': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f706d8>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70710>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70780>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f707b8>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70860>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f708d0>,
#  'this?': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70908>,
#  'Those': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70940>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70978>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f709b0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f709e8>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70a20>,
#  "couldn't.": <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70a58>,
#  'What': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70a90>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70ac8>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70b00>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70be0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70c18>,
#  'ceased': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70c50>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70c88>,
#  '(a': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70cc0>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70cf8>,
#  'Day': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70d30>,
#  'After': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70d68>,
#  'Tomorrow': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70da0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70dd8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70e10>,
#  'released': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70e80>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70ef0>,
#  "can't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70f28>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f70fd0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe70b8>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7240>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7278>,
#  'escapist': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe72e8>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe76d8>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7780>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7898>,
#  'effects)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7908>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7978>,
#  'preserve': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7a90>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7ac8>,
#  'somehow?': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7cc0>,
#  'Canada': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7da0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7e10>,
#  'food.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7eb8>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7f60>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fe7f98>,
#  'canning,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9048>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9080>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd90f0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9128>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9160>,
#  "wouldn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9208>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9278>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd92b0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9320>,
#  'went.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd93c8>,
#  'Better': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9470>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd94a8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9550>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd95c0>,
#  'case!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd96a0>,
#  "I've": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9828>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9898>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9940>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9a58>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9a90>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9ac8>,
#  'right.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9b38>,
#  'Then': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9ba8>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9c88>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9cc0>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9d30>,
#  'people,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9d68>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9dd8>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9e80>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9f28>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd9fd0>,
#  '(hmm,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdba20>,
#  'sounds': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdba90>,
#  'suspiciously': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbac8>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbc50>,
#  'else!)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbdd8>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbe10>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbef0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbf98>,
#  'try.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdbfd0>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb860>,
#  'notepad': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb128>,
#  'McNally': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb160>,
#  '(the': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb1d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb208>,
#  'bookstore': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb358>,
#  'Western': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb400>,
#  'Canada)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb588>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb5f8>,
#  '50s': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb668>,
#  'housewife': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb6d8>,
#  'grinning': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb748>,
#  'desperately.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdb828>,
#  'Each': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc080>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc128>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc278>,
#  '"New': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc2e8>,
#  'curtains!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc358>,
#  'Hurrah!".': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc400>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc438>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc4a8>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc550>,
#  'struck': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc5f8>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc630>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc6a0>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc6d8>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc710>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc908>,
#  'since.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc9b0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdc9e8>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdca58>,
#  'thinking?': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcac8>,
#  '20th': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcb38>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcba8>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcbe0>,
#  'reunion': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcc88>,
#  'weekend.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdccf8>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcda0>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcdd8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdce10>,
#  'coming,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdce48>,
#  'time.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcf98>,
#  'Lots': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fdcfd0>,
#  'names': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc080>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc128>,
#  'past.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc4a8>,
#  'Funny,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc518>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc668>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc748>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcc940>,
#  'anyone,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fccb38>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fccbe0>,
#  'city.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcccf8>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fccef0>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fccfd0>,
#  'Friday': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd048>,
#  'nights.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd0b8>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd1d0>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd208>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd240>,
#  '"what': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd5f8>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd630>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd6d8>,
#  'dinner"': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd898>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd908>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd978>,
#  'it.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcd9b0>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcdb38>,
#  'fact,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcdcc0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcdd30>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcde48>,
#  'too!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcdef0>,
#  'But': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce048>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce208>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce278>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce400>,
#  'gathering': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce4a8>,
#  "mom's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce5f8>,
#  'offered': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fce7f0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcea58>,
#  'kids.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf0f0>,
#  'So': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf128>,
#  'madly': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf208>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf2b0>,
#  'dough': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf358>,
#  'breadmaker': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf438>,
#  '(which': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf4e0>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf5c0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf5f8>,
#  'done)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf668>,
#  'freezing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf908>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcf9b0>,
#  'vegetables': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcfa58>,
#  'vegetarian': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcfba8>,
#  "cousins'": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcfbe0>,
#  'pizzas': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcfd30>,
#  'grate': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd00f0>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0128>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0198>,
#  'cheese.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd02b0>,
#  "I'll": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0390>,
#  'cart': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd03c8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0518>,
#  'wrecking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0710>,
#  'crusts.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0ac8>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0b00>,
#  'relaxing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0b70>,
#  'night,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0ba8>,
#  "hasn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0d68>,
#  'relaxed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0dd8>,
#  'all.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0ef0>,
#  'Okay,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0f98>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd0fd0>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe0f0>,
#  'Not': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe160>,
#  'Independence': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe2b0>,
#  'sure.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe390>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe5c0>,
#  'Raising': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe828>,
#  'Helen': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbe898>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbeb00>,
#  'saw.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf128>,
#  'Yes,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf160>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf5f8>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf6a0>,
#  'weekend!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf7f0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbf898>,
#  'club,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbfc18>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbfcf8>,
#  "hadn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbfd68>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fbfda0>,
#  'forever.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc1048>,
#  'Guess': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc1080>,
#  'whom...': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc1860>,
#  'cataloguing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc1898>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc1e48>,
#  'scripts': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2048>,
#  'work.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2080>,
#  'fun!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2128>,
#  'writers': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2208>,
#  'IMDB': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2358>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc23c8>,
#  'database!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2400>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2630>,
#  'mistakes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc2a20>,
#  'there,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3048>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc30b8>,
#  'information,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3198>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3240>,
#  'happen.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3278>,
#  'And': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc33c8>,
#  'links!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc36a0>,
#  'Library': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3780>,
#  'catalogues': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3940>,
#  'good.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc39b0>,
#  'Best': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc39e8>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3d30>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3f28>,
#  'sneak': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc3f60>,
#  'peek': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4320>,
#  "people's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4438>,
#  'lives.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc45c0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4710>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4748>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4780>,
#  'imagination': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4ba8>,
#  'going...': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4c50>,
#  'Paul': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4cc0>,
#  'Martin': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4d30>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4e48>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc4fd0>,
#  'elected': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc84a8>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc84e0>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8518>,
#  '250,000': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8710>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8748>,
#  'affordable': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8908>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc89b0>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8cc0>,
#  'spaces.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8e80>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8f28>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8f60>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc8f98>,
#  'too.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9128>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc91d0>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9320>,
#  'women,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9390>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9400>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9470>,
#  'families.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9518>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc97b8>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9828>,
#  'helpful,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9908>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9978>,
#  'children,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9c88>,
#  'flexible': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9d68>,
#  'arrangements.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9dd8>,
#  'Instead': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9e10>,
#  "year's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9e80>,
#  'maternity': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9eb8>,
#  'leave,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc9f98>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbc50>,
#  'mandatory': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbc88>,
#  'employers': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbcf8>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbdd8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbef0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbf28>,
#  'part-time': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcbf98>,
#  'If': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb048>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb1d0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb208>,
#  '50%': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb320>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb470>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb4a8>,
#  'us.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb588>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb5f8>,
#  'moms.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb630>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb828>,
#  'spaces': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb8d0>,
#  'too,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fcb908>,
#  'impossible': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5630>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5080>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc50f0>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5208>,
#  'quitting': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5240>,
#  'job.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc52b0>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5320>,
#  'ineveitable': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5390>,
#  'now...': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5400>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc54a8>,
#  'when.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5860>,
#  'No,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5898>,
#  "haven't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc59e8>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5a90>,
#  'it,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5b00>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5ba8>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5be0>,
#  'librarian.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5d30>,
#  'am!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5dd8>,
#  'over!': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5e10>,
#  'people.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5f28>,
#  'Most': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5f98>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc5fd0>,
#  'much,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6160>,
#  'deal.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6208>,
#  'Funny': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6278>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc62b0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6358>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6400>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6438>,
#  'are.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc64e0>,
#  'Anyway,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6518>,
#  'glad.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc65c0>,
#  'very,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc66a0>,
#  'tired': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc69e8>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6b00>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6cc0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6dd8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6e10>,
#  'snooze': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6f28>,
#  'bit.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6f60>,
#  'astute': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6048>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fc6080>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1128>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1240>,
#  'shorter': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd13c8>,
#  '5th': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1400>,
#  'one.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1438>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1668>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd16a0>,
#  'running,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd16d8>,
#  'walking--which': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1710>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1748>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1828>,
#  'run-walk': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1978>,
#  'ratio.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd19b0>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1a58>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1b00>,
#  '4th': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1b70>,
#  'repetition,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1be0>,
#  'difficult,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1c18>,
#  'struggled': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1c50>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1c88>,
#  'Tonight': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1d30>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1da0>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1dd8>,
#  'sensation.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1e10>,
#  'While': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1e48>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1ef0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1f60>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd1f98>,
#  'breaks,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4128>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4160>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd42e8>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4390>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4400>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4470>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4518>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4550>,
#  'invigorated.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4588>,
#  "there's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd45c0>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4710>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4748>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd47b8>,
#  'phenomenon.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd47f0>,
#  'However,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4828>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4860>,
#  'really,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4898>,
#  "tonight's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4978>,
#  'over.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd49e8>,
#  'pressing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4a20>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4a90>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4ac8>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4b38>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4b70>,
#  'decrease': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4c18>,
#  'Since': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4c88>,
#  'schedule': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4cf8>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4d30>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4d68>,
#  'time,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4da0>,
#  'that.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4e48>,
#  "They're": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4eb8>,
#  'experts,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd4fd0>,
#  "all--I'm": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd51d0>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5208>,
#  'shoes.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5240>,
#  "didn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5278>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd52b0>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd52e8>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5390>,
#  '"good,"': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd53c8>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5470>,
#  'either.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd54e0>,
#  'Actually,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5630>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5668>,
#  'repetition': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5748>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5780>,
#  'bucks;': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd57f0>,
#  'fourth,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5860>,
#  'flagged': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5940>,
#  '7th': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd59b0>,
#  'lungs': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd59e8>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5a20>,
#  'out.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5ac8>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5b38>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5b70>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5ba8>,
#  'repetitions,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5be0>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5c18>,
#  'told,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5c88>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5cc0>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5cf8>,
#  'Wednesday.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5d68>,
#  'Jon': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5da0>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5dd8>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5e10>,
#  'too;': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5e48>,
#  "he's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5eb8>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5ef0>,
#  'running.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5f28>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd5fd0>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd60b8>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd60f0>,
#  'him.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6160>,
#  'Today': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6198>,
#  'jogger': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd61d0>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6208>,
#  'runner--I': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6278>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd62b0>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd62e8>,
#  '(chocolate': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6358>,
#  'syrup,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6390>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd63c8>,
#  'cream,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6400>,
#  'crisps,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd64a8>,
#  'pizza,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd66a0>,
#  'etc.)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd67f0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6828>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd68d0>,
#  'days.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6978>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6ac8>,
#  'assure': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6b00>,
#  'laughably': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6c50>,
#  'easy.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6c88>,
#  "wasn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6cc0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6d30>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6d68>,
#  'painful.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6da0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6e48>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6e80>,
#  'going.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd6eb8>,
#  'to.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7390>,
#  'die.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd73c8>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd74a8>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7518>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd77b8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd78d0>,
#  'repetitions.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7978>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd79e8>,
#  'sorts': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7a20>,
#  'excuses': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7a58>,
#  'figured': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7b70>,
#  'out:': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7be0>,
#  'midday': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7c50>,
#  'sun;': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7dd8>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7e10>,
#  'uneven': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7e48>,
#  'ground,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7f28>,
#  'vaguely': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7f60>,
#  'hung-over.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7f98>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7320>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7128>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7160>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7198>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd7240>,
#  'wussed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1fd72e8>,
# ...
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71438>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71470>,
#  'times.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f714a8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f714e0>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71518>,
#  'fine;': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71550>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71588>,
#  'world.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f715c0>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f715f8>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71630>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71668>,
#  '5th,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f716a0>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f716d8>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71710>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71748>,
#  'expected,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71780>,
#  'slogged': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f717b8>,
#  '6th.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f717f0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71828>,
#  'struggle.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71860>,
#  'literally': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71898>,
#  'forcing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f718d0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71908>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71940>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71978>,
#  'other.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f719b0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f719e8>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71a20>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71a58>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71a90>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71ac8>,
#  'Psychologically,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71b00>,
#  'upsetting.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71b38>,
#  'sidewalks': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71b70>,
#  'paranoid': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71ba8>,
#  'fantasy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71be0>,
#  'runners': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71c18>,
#  'themselves,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71c50>,
#  "they're": <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71c88>,
#  'critiquing': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71cc0>,
#  'When': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71cf8>,
#  'down,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71d30>,
#  'sprint': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71d68>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71da0>,
#  'Even': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71dd8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71e10>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71e48>,
#  'runner': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71e80>,
#  'means,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71eb8>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71ef0>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71f28>,
#  'jog.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71f60>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71f98>,
#  'week,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f71fd0>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c048>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c080>,
#  'run.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c0b8>,
#  'laugh': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c0f0>,
#  'Saturday': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c128>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c160>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c198>,
#  'Edinburgh,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c1d0>,
#  'usual,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c208>,
#  'meantime,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c240>,
#  'however,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c278>,
#  'knee': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c2b0>,
#  'fantastic.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c2e8>,
#  'ACL': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c320>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c358>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c390>,
#  'tone,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c3c8>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c400>,
#  'kneecap': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c438>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c470>,
#  'properly,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c4a8>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c4e0>,
#  'clicking': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c518>,
#  'aching': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c550>,
#  'walking,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c588>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c5c0>,
#  'steps.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c5f8>,
#  'Now,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c630>,
#  'runs,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c668>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c6a0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c6d8>,
#  'stairs.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c710>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c748>,
#  'normal,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c780>,
#  'granted.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c7b8>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c7f0>,
#  '(repeated': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c828>,
#  'times),': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c860>,
#  'recommended': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c898>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c8d0>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c908>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c940>,
#  'use.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c978>,
#  'admit': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c9b0>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8c9e8>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ca20>,
#  'sweat.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ca58>,
#  'Because': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ca90>,
#  'easy,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cac8>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cb00>,
#  'in-between': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cb38>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cb70>,
#  'definite': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cba8>,
#  'advantages': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cbe0>,
#  'disadvantages': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cc18>,
#  'both.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cc50>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cc88>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ccc0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ccf8>,
#  '10k': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cd30>,
#  'schedule,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cd68>,
#  'tonight--my': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cda0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cdd8>,
#  'out--was': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ce10>,
#  'tester,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ce48>,
#  'ran': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ce80>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8ceb8>,
#  'minute,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cef0>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cf28>,
#  'reasonably': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cf60>,
#  'work,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cf98>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f8cfd0>,
#  'scary,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91048>,
#  'fine.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91080>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f910b8>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f910f0>,
#  'onto': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91128>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91160>,
#  'schedule.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91198>,
#  'Whoever': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f911d0>,
#  'reads': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91208>,
#  '(if': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91240>,
#  'anyone)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91278>,
#  'seriously.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f912b0>,
#  'am,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f912e8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91320>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91358>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91390>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f913c8>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91400>,
#  'up.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91438>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91470>,
#  'nights': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f914a8>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f914e0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91518>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91550>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91588>,
#  '(and': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f915c0>,
#  'precious': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f915f8>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91630>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91668>,
#  'TV': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f916a0>,
#  'on),': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f916d8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91710>,
#  'shattered': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91748>,
#  'sleep.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91780>,
#  'Fitting': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f917b8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f917f0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91828>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91860>,
#  'technically': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91898>,
#  'feasible,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f918d0>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91908>,
#  'attractive': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91940>,
#  'option.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91978>,
#  'Cycling,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f919b0>,
#  'medium.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f919e8>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91a20>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91a58>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91a90>,
#  'reasons:': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91ac8>,
#  '1)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91b00>,
#  'October,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91b38>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91b70>,
#  'cycling': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91ba8>,
#  'hurt.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91be0>,
#  'Running': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91c18>,
#  'ok,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91c50>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91c88>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91cc0>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91cf8>,
#  'badly': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91d30>,
#  "couldn't": <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91d68>,
#  'anymore.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91da0>,
#  '2)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91dd8>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91e10>,
#  'rusty.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91e48>,
#  'that)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91e80>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91eb8>,
#  'all,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91ef0>,
#  'go.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91f28>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91f60>,
#  'closer': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91f98>,
#  'inspection': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f91fd0>,
#  '(though': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93048>,
#  'replace': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93080>,
#  'it),': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f930b8>,
#  'braved': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f930f0>,
#  'cycled': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93128>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93160>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93198>,
#  'break,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f931d0>,
#  'afield,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93208>,
#  'hour.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93240>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93278>,
#  'hardest': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f932b0>,
#  'gears,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f932e8>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93320>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93358>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93390>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f933c8>,
#  '(because': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93400>,
#  'estimate': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93438>,
#  '80%': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93470>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f934a8>,
#  'now).': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f934e0>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93518>,
#  'reacts,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93550>,
#  'ok.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93588>,
#  'amazed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f935c0>,
#  'that,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f935f8>,
#  'lazy': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93630>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93668>,
#  'weeks,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f936a0>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f936d8>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93710>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93748>,
#  'minutes,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93780>,
#  '2,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f937b8>,
#  '4,': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f937f0>,
#  '7.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93828>,
#  "That's": <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93860>,
#  '(2)': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93898>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f938d0>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93908>,
#  'line.': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93940>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93978>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f939b0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f939e8>,
#  'reckon': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93a20>,
#  'fraction': <gensim.models.keyedvectors.Vocab at 0x7f1aa1f93a58>,
#  ...}

# %%
w2v.similarity('I', 'My')
# Out:
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.13654338311643185

# %%
print(posts[5])
w2v.similarity('ring', 'husband')
# Out:
# I've tried starting blog after blog and it just never feels right.  Then I read today that it feels strange to most people, but the more you do it the better it gets (hmm, sounds suspiciously like something else!) so I decided to give it another try.    My husband bought me a notepad at  urlLink McNally  (the best bookstore in Western Canada) with that title and a picture of a 50s housewife grinning desperately.  Each page has something funny like "New curtains!  Hurrah!".  For some reason it struck me as absolutely hilarious and has stuck in my head ever since.  What were those women thinking?
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# -0.03289733678047508

# %%
w2v.similarity('ring', 'housewife')
# Out:
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.01861962180809168

# %%
w2v.similarity('women', 'housewife')  # Diversity friendly
# Out:
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.071160876537917583

# %% [markdown]
# ## Doc2Vec
#
# The same technique of word2vec is extrapolated to documents. Here, we do everything done in word2vec + we vectorize the documents too

# %%
import numpy as np

# %%
# 0 for male, 1 for female
y_posts = np.concatenate((np.zeros(len(filtered_male_posts)),
                          np.ones(len(filtered_female_posts))))

# %%
len(y_posts)
# Out:
# 4842

# %% [markdown]
# # Convolutional Neural Networks for Sentence Classification

# %% [markdown]
# Train convolutional network for sentiment analysis.
#
# Based on
# "Convolutional Neural Networks for Sentence Classification" by Yoon Kim
# http://arxiv.org/pdf/1408.5882v2.pdf
#
# For 'CNN-non-static' gets to 82.1% after 61 epochs with following settings:
# embedding_dim = 20
# filter_sizes = (3, 4)
# num_filters = 3
# dropout_prob = (0.7, 0.8)
# hidden_dims = 100
#
# For 'CNN-rand' gets to 78-79% after 7-8 epochs with following settings:
# embedding_dim = 20
# filter_sizes = (3, 4)
# num_filters = 150
# dropout_prob = (0.25, 0.5)
# hidden_dims = 150
#
# For 'CNN-static' gets to 75.4% after 7 epochs with following settings:
# embedding_dim = 100
# filter_sizes = (3, 4)
# num_filters = 150
# dropout_prob = (0.25, 0.5)
# hidden_dims = 150
#
# * it turns out that such a small data set as "Movie reviews with one
# sentence per review"  (Pang and Lee, 2005) requires much smaller network
# than the one introduced in the original article:
# - embedding dimension is only 20 (instead of 300; 'CNN-static' still requires ~100)
# - 2 filter sizes (instead of 3)
# - higher dropout probabilities and
# - 3 filters per filter size is enough for 'CNN-non-static' (instead of 100)
# - embedding initialization does not require prebuilt Google Word2Vec data.
# Training Word2Vec on the same "Movie reviews" data set is enough to
# achieve performance reported in the article (81.6%)
#
# ** Another distinct difference is slidind MaxPooling window of length=2
# instead of MaxPooling over whole feature map as in the article

# %%
import numpy as np
import word_embedding
from word2vec import train_word2vec

from keras.models import Sequential, Model
from keras.layers import (Activation, Dense, Dropout, Embedding, 
                          Flatten, Input, 
                          Conv1D, MaxPooling1D)
from keras.layers.merge import Concatenate

np.random.seed(2)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Parameters
#
# Model Variations. See Kim Yoon's Convolutional Neural Networks for
# Sentence Classification, Section 3 for detail.

# %%
model_variation = 'CNN-rand'  #  CNN-rand | CNN-non-static | CNN-static
print('Model variation is %s' % model_variation)
# Out:
# Model variation is CNN-rand

# %%
# Model Hyperparameters
sequence_length = 56
embedding_dim = 20          
filter_sizes = (3, 4)
num_filters = 150
dropout_prob = (0.25, 0.5)
hidden_dims = 150

# %%
# Training parameters
batch_size = 32
num_epochs = 100
val_split = 0.1

# %%
# Word2Vec parameters, see train_word2vec
min_word_count = 1  # Minimum word count                        
context = 10        # Context window size

# %% [markdown]
# ### Data Preparation

# %%
# Load data
print("Loading data...")
x, y, vocabulary, vocabulary_inv = word_embedding.load_data()

if model_variation=='CNN-non-static' or model_variation=='CNN-static':
    embedding_weights = train_word2vec(x, vocabulary_inv, 
                                       embedding_dim, min_word_count, 
                                       context)
    if model_variation=='CNN-static':
        x = embedding_weights[0][x]
elif model_variation=='CNN-rand':
    embedding_weights = None
else:
    raise ValueError('Unknown model variation')
# Out:
# Loading data...

# %%
# Shuffle data
shuffle_indices = np.random.permutation(np.arange(len(y)))
x_shuffled = x[shuffle_indices]
y_shuffled = y[shuffle_indices].argmax(axis=1)

# %%
print("Vocabulary Size: {:d}".format(len(vocabulary)))
# Out:
# Vocabulary Size: 18765

# %% [markdown]
# ### Building CNN Model

# %%
graph_in = Input(shape=(sequence_length, embedding_dim))
convs = []
for fsz in filter_sizes:
    conv = Conv1D(filters=num_filters,
                  filter_length=fsz,
                  padding='valid',
                  activation='relu',
                  strides=1)(graph_in)
    pool = MaxPooling1D(pool_length=2)(conv)
    flatten = Flatten()(pool)
    convs.append(flatten)
    
if len(filter_sizes)>1:
    out = Concatenate()(convs)
else:
    out = convs[0]

graph = Model(input=graph_in, output=out)

# main sequential model
model = Sequential()
if not model_variation=='CNN-static':
    model.add(Embedding(len(vocabulary), embedding_dim, input_length=sequence_length,
                        weights=embedding_weights))
model.add(Dropout(dropout_prob[0], input_shape=(sequence_length, embedding_dim)))
model.add(graph)
model.add(Dense(hidden_dims))
model.add(Dropout(dropout_prob[1]))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(filters=150, padding="valid", activation="relu", strides=1, kernel_size=3)`
#
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `MaxPooling1D` call to the Keras 2 API: `MaxPooling1D(pool_size=2)`
#   if __name__ == '__main__':
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(filters=150, padding="valid", activation="relu", strides=1, kernel_size=4)`
#
# /srv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', 
              metrics=['accuracy'])

# Training model
# ==================================================
model.fit(x_shuffled, y_shuffled, batch_size=batch_size,
          nb_epoch=num_epochs, validation_split=val_split, verbose=2)
# Out:
# /srv/venv/lib/python3.6/site-packages/keras/models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 9595 samples, validate on 1067 samples
# Epoch 1/100
#  - 14s - loss: 0.6509 - acc: 0.6056 - val_loss: 0.5621 - val_acc: 0.7170
# Epoch 2/100
#  - 14s - loss: 0.4515 - acc: 0.7956 - val_loss: 0.5345 - val_acc: 0.7498
# Epoch 3/100
#  - 14s - loss: 0.3507 - acc: 0.8515 - val_loss: 0.5126 - val_acc: 0.7760
# Epoch 4/100
#  - 14s - loss: 0.2906 - acc: 0.8782 - val_loss: 0.5290 - val_acc: 0.7676
# Epoch 5/100
#  - 14s - loss: 0.2416 - acc: 0.9032 - val_loss: 0.5519 - val_acc: 0.7798
# Epoch 6/100
#  - 14s - loss: 0.1992 - acc: 0.9227 - val_loss: 0.6090 - val_acc: 0.7788
# Epoch 7/100
#  - 13s - loss: 0.1544 - acc: 0.9410 - val_loss: 0.6367 - val_acc: 0.7788
# Epoch 8/100
#  - 14s - loss: 0.1212 - acc: 0.9541 - val_loss: 0.7196 - val_acc: 0.7732
# Epoch 9/100
#  - 14s - loss: 0.0950 - acc: 0.9658 - val_loss: 0.8137 - val_acc: 0.7638
# Epoch 10/100
#  - 14s - loss: 0.0686 - acc: 0.9749 - val_loss: 0.9962 - val_acc: 0.7563
# Epoch 11/100
#  - 14s - loss: 0.0526 - acc: 0.9820 - val_loss: 1.0139 - val_acc: 0.7610
# Epoch 12/100
#  - 14s - loss: 0.0400 - acc: 0.9858 - val_loss: 1.1537 - val_acc: 0.7657
# Epoch 13/100
#  - 14s - loss: 0.0301 - acc: 0.9899 - val_loss: 1.3149 - val_acc: 0.7563
# Epoch 14/100
#  - 14s - loss: 0.0203 - acc: 0.9930 - val_loss: 1.4771 - val_acc: 0.7619
# Epoch 15/100
#  - 14s - loss: 0.0171 - acc: 0.9939 - val_loss: 1.5602 - val_acc: 0.7629
# Epoch 16/100
#  - 14s - loss: 0.0155 - acc: 0.9958 - val_loss: 1.7353 - val_acc: 0.7507
# Epoch 17/100
#  - 14s - loss: 0.0144 - acc: 0.9955 - val_loss: 1.6974 - val_acc: 0.7535
# Epoch 18/100
#  - 13s - loss: 0.0116 - acc: 0.9965 - val_loss: 1.7792 - val_acc: 0.7591
# Epoch 19/100
#  - 14s - loss: 0.0077 - acc: 0.9974 - val_loss: 1.9404 - val_acc: 0.7610
# Epoch 20/100
#  - 14s - loss: 0.0118 - acc: 0.9970 - val_loss: 1.7885 - val_acc: 0.7666
# Epoch 21/100
#  - 14s - loss: 0.0057 - acc: 0.9978 - val_loss: 2.1726 - val_acc: 0.7516
# Epoch 22/100
#  - 15s - loss: 0.0061 - acc: 0.9984 - val_loss: 2.0791 - val_acc: 0.7666
# Epoch 23/100
#  - 16s - loss: 0.0052 - acc: 0.9984 - val_loss: 2.1823 - val_acc: 0.7629
# Epoch 24/100
#  - 16s - loss: 0.0049 - acc: 0.9990 - val_loss: 2.2365 - val_acc: 0.7657
# Epoch 25/100
#  - 15s - loss: 0.0047 - acc: 0.9989 - val_loss: 2.3490 - val_acc: 0.7470
# Epoch 26/100
#  - 14s - loss: 0.0091 - acc: 0.9980 - val_loss: 2.1728 - val_acc: 0.7685
# Epoch 27/100
#  - 14s - loss: 0.0043 - acc: 0.9990 - val_loss: 2.2075 - val_acc: 0.7535
# Epoch 28/100
#  - 14s - loss: 0.0034 - acc: 0.9986 - val_loss: 2.2937 - val_acc: 0.7648
# Epoch 29/100
#  - 14s - loss: 0.0041 - acc: 0.9992 - val_loss: 2.2881 - val_acc: 0.7582
# Epoch 30/100
#  - 13s - loss: 0.0032 - acc: 0.9995 - val_loss: 2.4280 - val_acc: 0.7516
# Epoch 31/100
#  - 13s - loss: 0.0043 - acc: 0.9992 - val_loss: 2.4397 - val_acc: 0.7526
# Epoch 32/100
#  - 15s - loss: 0.0050 - acc: 0.9987 - val_loss: 2.3210 - val_acc: 0.7610
# Epoch 33/100
#  - 14s - loss: 0.0029 - acc: 0.9993 - val_loss: 2.4581 - val_acc: 0.7563
# Epoch 34/100
#  - 14s - loss: 0.0015 - acc: 0.9997 - val_loss: 2.4443 - val_acc: 0.7760
# Epoch 35/100
#  - 14s - loss: 0.0048 - acc: 0.9991 - val_loss: 2.3223 - val_acc: 0.7694
# Epoch 36/100
#  - 14s - loss: 0.0034 - acc: 0.9991 - val_loss: 2.5722 - val_acc: 0.7479
# Epoch 37/100
#  - 14s - loss: 0.0054 - acc: 0.9991 - val_loss: 2.5244 - val_acc: 0.7563
# Epoch 38/100
#  - 14s - loss: 0.0030 - acc: 0.9991 - val_loss: 2.5634 - val_acc: 0.7666
# Epoch 39/100
#  - 14s - loss: 0.0058 - acc: 0.9993 - val_loss: 2.4632 - val_acc: 0.7685
# Epoch 40/100
#  - 15s - loss: 0.0018 - acc: 0.9996 - val_loss: 2.7599 - val_acc: 0.7507
# Epoch 41/100
#  - 13s - loss: 0.0034 - acc: 0.9995 - val_loss: 2.5211 - val_acc: 0.7713
# Epoch 42/100
#  - 14s - loss: 0.0019 - acc: 0.9996 - val_loss: 2.5377 - val_acc: 0.7676
# Epoch 43/100
#  - 14s - loss: 0.0019 - acc: 0.9996 - val_loss: 2.6082 - val_acc: 0.7732
# Epoch 44/100
#  - 14s - loss: 0.0020 - acc: 0.9994 - val_loss: 2.5527 - val_acc: 0.7694
# Epoch 45/100
#  - 14s - loss: 9.6639e-04 - acc: 0.9998 - val_loss: 2.6079 - val_acc: 0.7573
# Epoch 46/100
#  - 15s - loss: 0.0027 - acc: 0.9995 - val_loss: 2.4981 - val_acc: 0.7685
# Epoch 47/100
#  - 14s - loss: 0.0043 - acc: 0.9991 - val_loss: 2.5658 - val_acc: 0.7704
# Epoch 48/100
#  - 14s - loss: 0.0052 - acc: 0.9989 - val_loss: 2.5606 - val_acc: 0.7535
# Epoch 49/100
#  - 14s - loss: 0.0019 - acc: 0.9995 - val_loss: 2.5671 - val_acc: 0.7563
# Epoch 50/100
#  - 14s - loss: 0.0028 - acc: 0.9996 - val_loss: 2.5257 - val_acc: 0.7751
# Epoch 51/100
#  - 14s - loss: 0.0031 - acc: 0.9995 - val_loss: 2.5130 - val_acc: 0.7779
# Epoch 52/100
#  - 14s - loss: 0.0030 - acc: 0.9994 - val_loss: 2.5257 - val_acc: 0.7779
# Epoch 53/100
#  - 13s - loss: 0.0024 - acc: 0.9992 - val_loss: 2.6731 - val_acc: 0.7619
# Epoch 54/100
#  - 14s - loss: 0.0060 - acc: 0.9990 - val_loss: 2.6440 - val_acc: 0.7657
# Epoch 55/100
#  - 14s - loss: 0.0042 - acc: 0.9994 - val_loss: 2.5883 - val_acc: 0.7648
# Epoch 56/100
#  - 14s - loss: 0.0034 - acc: 0.9995 - val_loss: 2.5049 - val_acc: 0.7779
# Epoch 57/100
#  - 14s - loss: 0.0019 - acc: 0.9998 - val_loss: 2.5789 - val_acc: 0.7901
# Epoch 58/100
#  - 15s - loss: 0.0012 - acc: 0.9998 - val_loss: 2.7636 - val_acc: 0.7629
# Epoch 59/100
#  - 14s - loss: 0.0045 - acc: 0.9996 - val_loss: 2.5659 - val_acc: 0.7798
# Epoch 60/100
#  - 14s - loss: 0.0054 - acc: 0.9993 - val_loss: 2.5121 - val_acc: 0.7816
# Epoch 61/100
#  - 14s - loss: 6.7672e-04 - acc: 0.9997 - val_loss: 2.5913 - val_acc: 0.7779
# Epoch 62/100
#  - 14s - loss: 0.0047 - acc: 0.9993 - val_loss: 2.5730 - val_acc: 0.7760
# Epoch 63/100
#  - 14s - loss: 0.0056 - acc: 0.9994 - val_loss: 2.5394 - val_acc: 0.7723
# Epoch 64/100
#  - 14s - loss: 0.0025 - acc: 0.9997 - val_loss: 2.6502 - val_acc: 0.7638
# Epoch 65/100
#  - 13s - loss: 8.7911e-04 - acc: 0.9999 - val_loss: 2.6154 - val_acc: 0.7760
# Epoch 66/100
#  - 13s - loss: 0.0030 - acc: 0.9995 - val_loss: 2.6191 - val_acc: 0.7723
# Epoch 67/100
#  - 14s - loss: 0.0031 - acc: 0.9995 - val_loss: 2.7097 - val_acc: 0.7779
# Epoch 68/100
#  - 13s - loss: 0.0035 - acc: 0.9995 - val_loss: 2.6783 - val_acc: 0.7732
# Epoch 69/100
#  - 14s - loss: 0.0042 - acc: 0.9992 - val_loss: 2.6182 - val_acc: 0.7779
# Epoch 70/100
#  - 14s - loss: 0.0023 - acc: 0.9994 - val_loss: 2.8561 - val_acc: 0.7601
# Epoch 71/100
#  - 14s - loss: 0.0026 - acc: 0.9996 - val_loss: 2.7159 - val_acc: 0.7685
# Epoch 72/100
#  - 14s - loss: 9.3670e-04 - acc: 0.9996 - val_loss: 2.6736 - val_acc: 0.7732
# Epoch 73/100
#  - 13s - loss: 0.0017 - acc: 0.9997 - val_loss: 2.7190 - val_acc: 0.7741
# Epoch 74/100
#  - 13s - loss: 0.0032 - acc: 0.9996 - val_loss: 2.6937 - val_acc: 0.7694
# Epoch 75/100
#  - 14s - loss: 0.0041 - acc: 0.9992 - val_loss: 2.6611 - val_acc: 0.7685
# Epoch 76/100
#  - 13s - loss: 0.0029 - acc: 0.9996 - val_loss: 2.7547 - val_acc: 0.7619
# Epoch 77/100
#  - 13s - loss: 0.0041 - acc: 0.9997 - val_loss: 2.8058 - val_acc: 0.7732
# Epoch 78/100
#  - 14s - loss: 0.0030 - acc: 0.9994 - val_loss: 2.7451 - val_acc: 0.7760
# Epoch 79/100
#  - 14s - loss: 0.0049 - acc: 0.9991 - val_loss: 2.9016 - val_acc: 0.7638
# Epoch 80/100
#  - 14s - loss: 0.0021 - acc: 0.9996 - val_loss: 2.7750 - val_acc: 0.7694
# Epoch 81/100
#  - 14s - loss: 0.0021 - acc: 0.9996 - val_loss: 2.7649 - val_acc: 0.7732
# Epoch 82/100
#  - 14s - loss: 0.0010 - acc: 0.9998 - val_loss: 2.7924 - val_acc: 0.7723
# Epoch 83/100
#  - 15s - loss: 0.0047 - acc: 0.9994 - val_loss: 2.8416 - val_acc: 0.7694
# Epoch 84/100
#  - 14s - loss: 5.1455e-04 - acc: 0.9998 - val_loss: 2.7845 - val_acc: 0.7779
# Epoch 85/100
#  - 15s - loss: 5.2041e-04 - acc: 0.9999 - val_loss: 2.8475 - val_acc: 0.7704
# Epoch 86/100
#  - 14s - loss: 0.0029 - acc: 0.9996 - val_loss: 2.8361 - val_acc: 0.7685
# Epoch 87/100
#  - 13s - loss: 0.0034 - acc: 0.9996 - val_loss: 2.8264 - val_acc: 0.7563
# Epoch 88/100
#  - 12s - loss: 0.0029 - acc: 0.9995 - val_loss: 3.0059 - val_acc: 0.7507
# Epoch 89/100
#  - 13s - loss: 0.0014 - acc: 0.9995 - val_loss: 2.8972 - val_acc: 0.7685
# Epoch 90/100
#  - 14s - loss: 8.2235e-04 - acc: 0.9999 - val_loss: 2.8683 - val_acc: 0.7685
# Epoch 91/100
#  - 13s - loss: 0.0032 - acc: 0.9995 - val_loss: 2.8156 - val_acc: 0.7704
# Epoch 92/100
#  - 14s - loss: 0.0037 - acc: 0.9996 - val_loss: 2.8997 - val_acc: 0.7619
# Epoch 93/100
#  - 14s - loss: 0.0019 - acc: 0.9997 - val_loss: 2.8450 - val_acc: 0.7676
# Epoch 94/100
#  - 14s - loss: 4.4296e-04 - acc: 0.9998 - val_loss: 2.8763 - val_acc: 0.7582
# Epoch 95/100
#  - 15s - loss: 0.0013 - acc: 0.9998 - val_loss: 2.8912 - val_acc: 0.7657
# Epoch 96/100
#  - 13s - loss: 0.0039 - acc: 0.9996 - val_loss: 2.9395 - val_acc: 0.7582
# Epoch 97/100
#  - 14s - loss: 0.0012 - acc: 0.9998 - val_loss: 2.8856 - val_acc: 0.7629
# Epoch 98/100
#  - 14s - loss: 0.0016 - acc: 0.9997 - val_loss: 2.9311 - val_acc: 0.7648
# Epoch 99/100
#  - 13s - loss: 0.0035 - acc: 0.9992 - val_loss: 2.9319 - val_acc: 0.7666
# Epoch 100/100
#  - 13s - loss: 8.7101e-04 - acc: 0.9998 - val_loss: 2.8998 - val_acc: 0.7601

# %% [markdown]
# # Another Example
#
# Using Keras + [**GloVe**](http://nlp.stanford.edu/projects/glove/) - **Global Vectors for Word Representation**

# %% [markdown]
# done ; Gopal
