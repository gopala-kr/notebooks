# %% [markdown]
# # Working with Bag of Words
#
# -------------------------------------
#
# In this example, we will download and preprocess the ham/spam text data.  We will then use a one-hot-encoding to make a bag of words set of features to use in logistic regression.
#
# We will use these one-hot-vectors for logistic regression to predict if a text is spam or ham.
#
# We start by loading the necessary libraries.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import csv
import string
import requests
import io
from zipfile import ZipFile
from tensorflow.contrib import learn
from tensorflow.python.framework import ops
ops.reset_default_graph()
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# We start a computation graph session.

# %%
# Start a graph session
sess = tf.Session()

# %% [markdown]
# Check if data was downloaded, otherwise download it and save for future use

# %%
save_file_name = os.path.join('temp','temp_spam_data.csv')

# Create directory if it doesn't exist
if not os.path.exists('temp'):
    os.makedirs('temp')

if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerows(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

# %% [markdown]
# To reduce the potential vocabulary size, we normalize the text. To do this, we remove the influence of capitalization and numbers in the text.

# %%
# Relabel 'spam' as 1, 'ham' as 0
target = [1 if x=='spam' else 0 for x in target]

# Normalize text
# Lower case
texts = [x.lower() for x in texts]

# Remove punctuation
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]

# Remove numbers
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

# Trim extra whitespace
texts = [' '.join(x.split()) for x in texts]

# %% [markdown]
# To determine a good sentence length to pad/crop at, we plot a histogram of text lengths (in words).

# %%
# %matplotlib inline
# Plot histogram of text lengths
text_lengths = [len(x.split()) for x in texts]
text_lengths = [x for x in text_lengths if x < 50]
plt.hist(text_lengths, bins=25)
plt.title('Histogram of # of Words in Texts')
plt.show()

# %% [markdown]
# We crop/pad all texts to be 25 words long.  We also will filter out any words that do not appear at least 3 times.

# %%
# Choose max text word length at 25
sentence_size = 25
min_word_freq = 3

# %% [markdown]
# TensorFlow has a built in text processing function called `VocabularyProcessor()`. We use this function to process the texts.

# %%
# Setup vocabulary processor
vocab_processor = learn.preprocessing.VocabularyProcessor(sentence_size, min_frequency=min_word_freq)

# Have to fit transform to get length of unique words.
vocab_processor.transform(texts)
embedding_size = len([x for x in vocab_processor.transform(texts)])

# %% [markdown]
# To test our logistic model (predicting spam/ham), we split the texts into a train and test set.

# %%
# Split up data set into train/test
train_indices = np.random.choice(len(texts), round(len(texts)*0.8), replace=False)
test_indices = np.array(list(set(range(len(texts))) - set(train_indices)))
texts_train = [x for ix, x in enumerate(texts) if ix in train_indices]
texts_test = [x for ix, x in enumerate(texts) if ix in test_indices]
target_train = [x for ix, x in enumerate(target) if ix in train_indices]
target_test = [x for ix, x in enumerate(target) if ix in test_indices]

# %% [markdown]
# For one-hot-encoding, we setup an identity matrix for the TensorFlow embedding lookup.
#
# We also create the variables and placeholders for the logistic regression we will perform.

# %%
# Setup Index Matrix for one-hot-encoding
identity_mat = tf.diag(tf.ones(shape=[embedding_size]))

# Create variables for logistic regression
A = tf.Variable(tf.random_normal(shape=[embedding_size,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# Initialize placeholders
x_data = tf.placeholder(shape=[sentence_size], dtype=tf.int32)
y_target = tf.placeholder(shape=[1, 1], dtype=tf.float32)

# %% [markdown]
# Next, we create the text-word embedding lookup with the prior identity matrix.
#
# Our logistic regression will use the counts of the words as the input.  The counts are created by summing the embedding output across the rows.
#
# Then we declare the logistic regression operations. Note that we do not wrap the logistic operations in the sigmoid function because this will be done in the loss function later on.

# %%
# Text-Vocab Embedding
x_embed = tf.nn.embedding_lookup(identity_mat, x_data)
x_col_sums = tf.reduce_sum(x_embed, 0)

# Declare model operations
x_col_sums_2D = tf.expand_dims(x_col_sums, 0)
model_output = tf.add(tf.matmul(x_col_sums_2D, A), b)

# %% [markdown]
# Now we declare our loss function (which has the sigmoid built in), prediction operations, optimizer, and initialize the variables.

# %%
# Declare loss function (Cross Entropy loss)
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

# Prediction operation
prediction = tf.sigmoid(model_output)

# Declare optimizer
my_opt = tf.train.GradientDescentOptimizer(0.001)
train_step = my_opt.minimize(loss)

# Intitialize Variables
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# Now we loop through the iterations and fit the logistic regression on wether or not the text is spam or ham.

# %%
# Start Logistic Regression
print('Starting Training Over {} Sentences.'.format(len(texts_train)))
loss_vec = []
train_acc_all = []
train_acc_avg = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_train)):
    y_data = [[target_train[ix]]]
    
    
    sess.run(train_step, feed_dict={x_data: t, y_target: y_data})
    temp_loss = sess.run(loss, feed_dict={x_data: t, y_target: y_data})
    loss_vec.append(temp_loss)
    
    if (ix+1)%10==0:
        print('Training Observation #' + str(ix+1) + ': Loss = ' + str(temp_loss))
        
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    train_acc_temp = target_train[ix]==np.round(temp_pred)
    train_acc_all.append(train_acc_temp)
    if len(train_acc_all) >= 50:
        train_acc_avg.append(np.mean(train_acc_all[-50:]))
# Out:
# Starting Training Over 4459 Sentences.
# Training Observation #10: Loss = 1.468791
# Training Observation #20: Loss = 8.050926
# Training Observation #30: Loss = 6.3969636
# Training Observation #40: Loss = 8.138696
# Training Observation #50: Loss = 3.7760785
# Training Observation #60: Loss = 0.018479379
# Training Observation #70: Loss = 4.3828783
# Training Observation #80: Loss = 0.018122427
# Training Observation #90: Loss = 0.33942223
# Training Observation #100: Loss = 0.11076284
# Training Observation #110: Loss = 1.7845527
# Training Observation #120: Loss = 0.024408095
# Training Observation #130: Loss = 1.5606809
# Training Observation #140: Loss = 2.0212862
# Training Observation #150: Loss = 0.002067604
# Training Observation #160: Loss = 0.05216483
# Training Observation #170: Loss = 0.0077601443
# Training Observation #180: Loss = 0.012838273
# Training Observation #190: Loss = 0.48382336
# Training Observation #200: Loss = 0.028859751
# Training Observation #210: Loss = 0.20473477
# Training Observation #220: Loss = 0.0057590194
# Training Observation #230: Loss = 1.26708
# Training Observation #240: Loss = 0.002767466
# Training Observation #250: Loss = 0.24043208
# Training Observation #260: Loss = 1.6675982
# Training Observation #270: Loss = 0.12967733
# Training Observation #280: Loss = 0.00028384084
# Training Observation #290: Loss = 5.1370816
# Training Observation #300: Loss = 0.19168128
# Training Observation #310: Loss = 0.0014055098
# Training Observation #320: Loss = 2.6509254
# Training Observation #330: Loss = 0.0038652348
# Training Observation #340: Loss = 0.0075390204
# Training Observation #350: Loss = 0.38500386
# Training Observation #360: Loss = 0.004802176
# Training Observation #370: Loss = 0.0008291514
# Training Observation #380: Loss = 9.497047e-05
# Training Observation #390: Loss = 0.00013575699
# Training Observation #400: Loss = 0.0013257076
# Training Observation #410: Loss = 0.00080263003
# Training Observation #420: Loss = 0.010203268
# Training Observation #430: Loss = 1.5517892
# Training Observation #440: Loss = 6.8607736
# Training Observation #450: Loss = 0.6000334
# Training Observation #460: Loss = 1.2739365
# Training Observation #470: Loss = 6.515698e-05
# Training Observation #480: Loss = 0.02900438
# Training Observation #490: Loss = 0.6579372
# Training Observation #500: Loss = 0.02640752
# Training Observation #510: Loss = 0.010877852
# Training Observation #520: Loss = 0.028052455
# Training Observation #530: Loss = 3.7276638
# Training Observation #540: Loss = 7.4405127
# Training Observation #550: Loss = 0.0004587564
# Training Observation #560: Loss = 0.0038069726
# Training Observation #570: Loss = 0.11992287
# Training Observation #580: Loss = 4.6851225
# Training Observation #590: Loss = 0.059607167
# Training Observation #600: Loss = 7.856397e-05
# Training Observation #610: Loss = 1.8649592
# Training Observation #620: Loss = 4.8987813
# Training Observation #630: Loss = 0.0068923985
# Training Observation #640: Loss = 0.001750026
# Training Observation #650: Loss = 0.032432448
# Training Observation #660: Loss = 0.45524883
# Training Observation #670: Loss = 0.28962994
# Training Observation #680: Loss = 0.5608845
# Training Observation #690: Loss = 9.618937e-05
# Training Observation #700: Loss = 0.0005158569
# Training Observation #710: Loss = 0.0015300001
# Training Observation #720: Loss = 0.0062128813
# Training Observation #730: Loss = 0.002620146
# Training Observation #740: Loss = 0.22142467
# Training Observation #750: Loss = 0.017896589
# Training Observation #760: Loss = 7.4460993
# Training Observation #770: Loss = 0.0045247087
# Training Observation #780: Loss = 0.39175218
# Training Observation #790: Loss = 0.00052059896
# Training Observation #800: Loss = 0.002420822
# Training Observation #810: Loss = 0.09179083
# Training Observation #820: Loss = 0.066593125
# Training Observation #830: Loss = 0.0003300382
# Training Observation #840: Loss = 1.2261384e-05
# Training Observation #850: Loss = 0.0007386425
# Training Observation #860: Loss = 8.7389904e-05
# Training Observation #870: Loss = 0.15721874
# Training Observation #880: Loss = 0.0015183797
# Training Observation #890: Loss = 1.6027873
# Training Observation #900: Loss = 4.040915e-05
# Training Observation #910: Loss = 0.0007678874
# Training Observation #920: Loss = 0.09284097
# Training Observation #930: Loss = 0.16292727
# Training Observation #940: Loss = 2.6576725e-05
# Training Observation #950: Loss = 0.9444897
# Training Observation #960: Loss = 9.704828e-05
# Training Observation #970: Loss = 6.640963
# Training Observation #980: Loss = 0.006310814
# Training Observation #990: Loss = 0.0012662811
# Training Observation #1000: Loss = 0.023555277
# Training Observation #1010: Loss = 0.0020794685
# Training Observation #1020: Loss = 5.225658
# Training Observation #1030: Loss = 0.010739677
# Training Observation #1040: Loss = 0.0022625488
# Training Observation #1050: Loss = 0.048407577
# Training Observation #1060: Loss = 0.00032316695
# Training Observation #1070: Loss = 0.0014981763
# Training Observation #1080: Loss = 3.6985023e-06
# Training Observation #1090: Loss = 0.0022541762
# Training Observation #1100: Loss = 0.00047328114
# Training Observation #1110: Loss = 0.044258628
# Training Observation #1120: Loss = 0.00031050268
# Training Observation #1130: Loss = 5.5732246e-05
# Training Observation #1140: Loss = 0.0035602252
# Training Observation #1150: Loss = 0.0008913723
# Training Observation #1160: Loss = 0.0020792496
# Training Observation #1170: Loss = 0.00025937677
# Training Observation #1180: Loss = 0.00012793536
# Training Observation #1190: Loss = 0.00040876452
# Training Observation #1200: Loss = 2.8390882
# Training Observation #1210: Loss = 0.0037242316
# Training Observation #1220: Loss = 0.00038930582
# Training Observation #1230: Loss = 4.3365362e-05
# Training Observation #1240: Loss = 4.413807e-05
# Training Observation #1250: Loss = 0.00035713107
# Training Observation #1260: Loss = 0.024698637
# Training Observation #1270: Loss = 2.054668e-05
# Training Observation #1280: Loss = 0.00011932991
# Training Observation #1290: Loss = 0.0075377277
# Training Observation #1300: Loss = 0.001943313
# Training Observation #1310: Loss = 4.2797933
# Training Observation #1320: Loss = 0.0026167282
# Training Observation #1330: Loss = 5.5248017
# Training Observation #1340: Loss = 3.7904174e-05
# Training Observation #1350: Loss = 0.00043153597
# Training Observation #1360: Loss = 5.9654874e-05
# Training Observation #1370: Loss = 0.0020068476
# Training Observation #1380: Loss = 0.00075742387
# Training Observation #1390: Loss = 0.00019344754
# Training Observation #1400: Loss = 6.536123e-05
# Training Observation #1410: Loss = 0.0591346
# Training Observation #1420: Loss = 7.5354977
# Training Observation #1430: Loss = 1.7725035
# Training Observation #1440: Loss = 0.040184505
# Training Observation #1450: Loss = 0.0018418093
# Training Observation #1460: Loss = 1.3715844
# Training Observation #1470: Loss = 9.092908e-06
# Training Observation #1480: Loss = 2.107841
# Training Observation #1490: Loss = 0.011153459
# Training Observation #1500: Loss = 0.93391776
# Training Observation #1510: Loss = 0.56045115
# Training Observation #1520: Loss = 5.4870052e-05
# Training Observation #1530: Loss = 0.03815698
# Training Observation #1540: Loss = 0.12289569
# Training Observation #1550: Loss = 0.15817994
# Training Observation #1560: Loss = 3.6645944
# Training Observation #1570: Loss = 3.1462366e-06
# Training Observation #1580: Loss = 0.011531314
# Training Observation #1590: Loss = 0.0001672363
# Training Observation #1600: Loss = 0.41061556
# Training Observation #1610: Loss = 0.0031902168
# Training Observation #1620: Loss = 6.785846
# Training Observation #1630: Loss = 2.3029675
# Training Observation #1640: Loss = 0.0036481011
# Training Observation #1650: Loss = 8.42449e-06
# Training Observation #1660: Loss = 0.18321416
# Training Observation #1670: Loss = 0.010077383
# Training Observation #1680: Loss = 0.00036014424
# Training Observation #1690: Loss = 1.2989709
# Training Observation #1700: Loss = 5.191983e-07
# Training Observation #1710: Loss = 0.00025033212
# Training Observation #1720: Loss = 5.9228878e-05
# Training Observation #1730: Loss = 0.0048104157
# Training Observation #1740: Loss = 3.3652348e-05
# Training Observation #1750: Loss = 0.0003006366
# Training Observation #1760: Loss = 0.03931248
# Training Observation #1770: Loss = 0.00028354273
# Training Observation #1780: Loss = 1.1566305
# Training Observation #1790: Loss = 2.4451294
# Training Observation #1800: Loss = 6.5350454e-05
# Training Observation #1810: Loss = 0.35902125
# Training Observation #1820: Loss = 0.006969585
# Training Observation #1830: Loss = 1.074214e-05
# Training Observation #1840: Loss = 0.0106953755
# Training Observation #1850: Loss = 1.7696288
# Training Observation #1860: Loss = 1.8396974
# Training Observation #1870: Loss = 7.574503e-06
# Training Observation #1880: Loss = 0.00011362361
# Training Observation #1890: Loss = 2.483043
# Training Observation #1900: Loss = 0.34775412
# Training Observation #1910: Loss = 0.004745246
# Training Observation #1920: Loss = 2.1448166e-05
# Training Observation #1930: Loss = 4.0640202e-06
# Training Observation #1940: Loss = 0.078226216
# Training Observation #1950: Loss = 5.439841
# Training Observation #1960: Loss = 0.00018809053
# Training Observation #1970: Loss = 2.9912328e-05
# Training Observation #1980: Loss = 1.4280934e-05
# Training Observation #1990: Loss = 1.3930562e-06
# Training Observation #2000: Loss = 0.43143815
# Training Observation #2010: Loss = 1.7239297e-05
# Training Observation #2020: Loss = 0.012547335
# Training Observation #2030: Loss = 6.436647e-05
# Training Observation #2040: Loss = 0.045713447
# Training Observation #2050: Loss = 0.5688502
# Training Observation #2060: Loss = 4.662096
# Training Observation #2070: Loss = 0.010490649
# Training Observation #2080: Loss = 0.54922605
# Training Observation #2090: Loss = 0.6714534
# Training Observation #2100: Loss = 0.0004806408
# Training Observation #2110: Loss = 1.1391817
# Training Observation #2120: Loss = 0.0018794639
# Training Observation #2130: Loss = 0.005168767
# Training Observation #2140: Loss = 1.4130301e-05
# Training Observation #2150: Loss = 0.0028089602
# Training Observation #2160: Loss = 0.00014421552
# Training Observation #2170: Loss = 1.309466e-05
# Training Observation #2180: Loss = 0.14903581
# Training Observation #2190: Loss = 1.1778186e-05
# Training Observation #2200: Loss = 0.00034254682
# Training Observation #2210: Loss = 1.9246264
# Training Observation #2220: Loss = 7.646071e-06
# Training Observation #2230: Loss = 0.03383637
# Training Observation #2240: Loss = 1.8362296e-05
# Training Observation #2250: Loss = 4.6320386
# Training Observation #2260: Loss = 0.0038833595
# Training Observation #2270: Loss = 3.61745e-06
# Training Observation #2280: Loss = 0.0007485822
# Training Observation #2290: Loss = 3.6925744e-06
# Training Observation #2300: Loss = 4.815407e-06
# Training Observation #2310: Loss = 0.24245194
# Training Observation #2320: Loss = 3.2810667e-06
# Training Observation #2330: Loss = 0.3229342
# Training Observation #2340: Loss = 8.8480704e-07
# Training Observation #2350: Loss = 0.0010866552
# Training Observation #2360: Loss = 0.00012561532
# Training Observation #2370: Loss = 0.025533387
# Training Observation #2380: Loss = 1.4853784e-05
# Training Observation #2390: Loss = 8.04547e-06
# Training Observation #2400: Loss = 0.00023678786
# Training Observation #2410: Loss = 0.00014621748
# Training Observation #2420: Loss = 0.00032823303
# Training Observation #2430: Loss = 4.5059573e-05
# Training Observation #2440: Loss = 0.0064439033
# Training Observation #2450: Loss = 2.534754
# Training Observation #2460: Loss = 0.0023785327
# Training Observation #2470: Loss = 9.9951416e-05
# Training Observation #2480: Loss = 0.011271478
# Training Observation #2490: Loss = 2.0736568e-06
# Training Observation #2500: Loss = 1.225509
# Training Observation #2510: Loss = 2.9914305
# Training Observation #2520: Loss = 5.339096e-07
# Training Observation #2530: Loss = 0.00014798256
# Training Observation #2540: Loss = 0.0011245343
# Training Observation #2550: Loss = 4.8104316e-06
# Training Observation #2560: Loss = 0.0669871
# Training Observation #2570: Loss = 0.0001074307
# Training Observation #2580: Loss = 0.006067281
# Training Observation #2590: Loss = 1.48025365e-05
# Training Observation #2600: Loss = 0.00033681348
# Training Observation #2610: Loss = 0.0109468885
# Training Observation #2620: Loss = 0.0005829149
# Training Observation #2630: Loss = 1.0768736e-05
# Training Observation #2640: Loss = 0.012547583
# Training Observation #2650: Loss = 0.02407586
# Training Observation #2660: Loss = 0.010615393
# Training Observation #2670: Loss = 3.577982e-05
# Training Observation #2680: Loss = 8.676292e-06
# Training Observation #2690: Loss = 1.1195979e-06
# Training Observation #2700: Loss = 0.0012243711
# Training Observation #2710: Loss = 3.7993648e-06
# Training Observation #2720: Loss = 4.878925e-06
# Training Observation #2730: Loss = 0.0009371166
# Training Observation #2740: Loss = 7.319286e-05
# Training Observation #2750: Loss = 0.25389138
# Training Observation #2760: Loss = 0.046231072
# Training Observation #2770: Loss = 6.265872e-05
# Training Observation #2780: Loss = 0.00451614
# Training Observation #2790: Loss = 0.0013286257
# Training Observation #2800: Loss = 4.560958e-06
# Training Observation #2810: Loss = 1.2847023e-05
# Training Observation #2820: Loss = 0.016378898
# Training Observation #2830: Loss = 4.9423006e-06
# Training Observation #2840: Loss = 4.9111888e-05
# Training Observation #2850: Loss = 4.9184093
# Training Observation #2860: Loss = 6.228132e-05
# Training Observation #2870: Loss = 0.0001095198
# Training Observation #2880: Loss = 0.052564457
# Training Observation #2890: Loss = 0.00043963967
# Training Observation #2900: Loss = 0.0018920461
# Training Observation #2910: Loss = 0.00074952695
# Training Observation #2920: Loss = 0.0037277038
# Training Observation #2930: Loss = 0.05462784
# Training Observation #2940: Loss = 8.2103405
# Training Observation #2950: Loss = 0.001246418
# Training Observation #2960: Loss = 0.00052535627
# Training Observation #2970: Loss = 2.3331237
# Training Observation #2980: Loss = 0.28033563
# Training Observation #2990: Loss = 0.00042078964
# Training Observation #3000: Loss = 2.4074874e-08
# Training Observation #3010: Loss = 0.00012031694
# Training Observation #3020: Loss = 0.0326384
# Training Observation #3030: Loss = 1.1166189
# Training Observation #3040: Loss = 0.0002921172
# Training Observation #3050: Loss = 0.00057005294
# Training Observation #3060: Loss = 2.2917146e-05
# Training Observation #3070: Loss = 0.0022026324
# Training Observation #3080: Loss = 0.00012440699
# Training Observation #3090: Loss = 0.02270835
# Training Observation #3100: Loss = 0.009312055
# Training Observation #3110: Loss = 0.00047951567
# Training Observation #3120: Loss = 0.022759713
# Training Observation #3130: Loss = 0.044570826
# Training Observation #3140: Loss = 0.00013881813
# Training Observation #3150: Loss = 0.00508122
# Training Observation #3160: Loss = 2.1361172
# Training Observation #3170: Loss = 0.00020614496
# Training Observation #3180: Loss = 7.1769824
# Training Observation #3190: Loss = 0.00044259217
# Training Observation #3200: Loss = 0.00025767653
# Training Observation #3210: Loss = 0.10719548
# Training Observation #3220: Loss = 0.0018616382
# Training Observation #3230: Loss = 3.471107
# Training Observation #3240: Loss = 2.4330177
# Training Observation #3250: Loss = 0.00032619876
# Training Observation #3260: Loss = 0.0010188724
# Training Observation #3270: Loss = 4.8518443e-05
# Training Observation #3280: Loss = 0.036126822
# Training Observation #3290: Loss = 0.0068586287
# Training Observation #3300: Loss = 8.058186
# Training Observation #3310: Loss = 0.004507237
# Training Observation #3320: Loss = 0.26320648
# Training Observation #3330: Loss = 0.00039715815
# Training Observation #3340: Loss = 2.6611066
# Training Observation #3350: Loss = 0.0003146641
# Training Observation #3360: Loss = 0.11647476
# Training Observation #3370: Loss = 0.00019950389
# Training Observation #3380: Loss = 1.6280445
# Training Observation #3390: Loss = 0.14920291
# Training Observation #3400: Loss = 0.050378133
# Training Observation #3410: Loss = 0.00013791928
# Training Observation #3420: Loss = 1.5386717
# Training Observation #3430: Loss = 3.902522
# Training Observation #3440: Loss = 0.0055330317
# Training Observation #3450: Loss = 0.026698552
# Training Observation #3460: Loss = 2.5711946
# Training Observation #3470: Loss = 2.5867707e-06
# Training Observation #3480: Loss = 0.00011734193
# Training Observation #3490: Loss = 0.15347931
# Training Observation #3500: Loss = 0.00030761323
# Training Observation #3510: Loss = 3.8152406
# Training Observation #3520: Loss = 0.002497865
# Training Observation #3530: Loss = 0.00028929702
# Training Observation #3540: Loss = 7.07605e-05
# Training Observation #3550: Loss = 0.004131978
# Training Observation #3560: Loss = 3.8262992
# Training Observation #3570: Loss = 0.69691074
# Training Observation #3580: Loss = 0.000118037984
# Training Observation #3590: Loss = 2.2489185
# Training Observation #3600: Loss = 0.000666346
# Training Observation #3610: Loss = 0.010179089
# Training Observation #3620: Loss = 0.00048294562
# Training Observation #3630: Loss = 0.0015884922
# Training Observation #3640: Loss = 0.0014589117
# Training Observation #3650: Loss = 0.5709569
# Training Observation #3660: Loss = 0.560006
# Training Observation #3670: Loss = 0.07500559
# Training Observation #3680: Loss = 1.4369405e-05
# Training Observation #3690: Loss = 0.56901765
# Training Observation #3700: Loss = 0.0022095244
# Training Observation #3710: Loss = 0.0040231817
# Training Observation #3720: Loss = 0.0018214632
# Training Observation #3730: Loss = 0.12691286
# Training Observation #3740: Loss = 0.003053854
# Training Observation #3750: Loss = 1.3789791e-05
# Training Observation #3760: Loss = 0.000773946
# Training Observation #3770: Loss = 0.0046025077
# Training Observation #3780: Loss = 3.2334194e-06
# Training Observation #3790: Loss = 0.0032426273
# Training Observation #3800: Loss = 0.021508846
# Training Observation #3810: Loss = 2.6756394e-05
# Training Observation #3820: Loss = 8.43272
# Training Observation #3830: Loss = 1.1911159e-05
# Training Observation #3840: Loss = 0.00013583753
# Training Observation #3850: Loss = 2.3509405e-05
# Training Observation #3860: Loss = 1.562931e-05
# Training Observation #3870: Loss = 1.62985e-05
# Training Observation #3880: Loss = 1.5719146e-05
# Training Observation #3890: Loss = 0.0002696345
# Training Observation #3900: Loss = 0.00035275827
# Training Observation #3910: Loss = 0.00015901336
# Training Observation #3920: Loss = 0.040104557
# Training Observation #3930: Loss = 0.00043601202
# Training Observation #3940: Loss = 0.001754871
# Training Observation #3950: Loss = 0.7256464
# Training Observation #3960: Loss = 0.0095770955
# Training Observation #3970: Loss = 0.0067172283
# Training Observation #3980: Loss = 0.00020586562
# Training Observation #3990: Loss = 0.0036634377
# Training Observation #4000: Loss = 0.0063545476
# Training Observation #4010: Loss = 3.5997074
# Training Observation #4020: Loss = 0.0008765519
# Training Observation #4030: Loss = 0.4260194
# Training Observation #4040: Loss = 8.695645
# Training Observation #4050: Loss = 3.055103
# Training Observation #4060: Loss = 0.00025721575
# Training Observation #4070: Loss = 0.0010397024
# Training Observation #4080: Loss = 0.004025227
# Training Observation #4090: Loss = 0.009684253
# Training Observation #4100: Loss = 0.00014134678
# Training Observation #4110: Loss = 5.7682395
# Training Observation #4120: Loss = 0.002248599
# Training Observation #4130: Loss = 1.8682309e-05
# Training Observation #4140: Loss = 9.208273e-05
# Training Observation #4150: Loss = 0.001086377
# Training Observation #4160: Loss = 6.373094e-05
# Training Observation #4170: Loss = 7.495982e-05
# Training Observation #4180: Loss = 5.9468453e-05
# Training Observation #4190: Loss = 0.0006695832
# Training Observation #4200: Loss = 0.45293605
# Training Observation #4210: Loss = 0.0035178538
# Training Observation #4220: Loss = 4.6861605e-05
# Training Observation #4230: Loss = 0.21538094
# Training Observation #4240: Loss = 1.9266309
# Training Observation #4250: Loss = 0.015160224
# Training Observation #4260: Loss = 0.025075838
# Training Observation #4270: Loss = 0.00030588836
# Training Observation #4280: Loss = 0.00014314354
# Training Observation #4290: Loss = 0.016063415
# Training Observation #4300: Loss = 5.469207
# Training Observation #4310: Loss = 4.6436505
# Training Observation #4320: Loss = 0.0054165656
# Training Observation #4330: Loss = 0.00029719353
# Training Observation #4340: Loss = 4.299899
# Training Observation #4350: Loss = 1.8096316e-05
# Training Observation #4360: Loss = 1.1261543
# Training Observation #4370: Loss = 3.2994406
# Training Observation #4380: Loss = 0.32751393
# Training Observation #4390: Loss = 0.0007524971
# Training Observation #4400: Loss = 0.14162385
# Training Observation #4410: Loss = 0.0008967612
# Training Observation #4420: Loss = 0.00029203953
# Training Observation #4430: Loss = 2.7212518e-05
# Training Observation #4440: Loss = 0.107835814
# Training Observation #4450: Loss = 0.0005716964

# %% [markdown]
# Now that we have a logistic model, we can evaluate the accuracy on the test dataset.

# %%
# Get test set accuracy
print('Getting Test Set Accuracy For {} Sentences.'.format(len(texts_test)))
test_acc_all = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_test)):
    y_data = [[target_test[ix]]]
    
    if (ix+1)%50==0:
        print('Test Observation #' + str(ix+1))    
    
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    test_acc_temp = target_test[ix]==np.round(temp_pred)
    test_acc_all.append(test_acc_temp)

print('\nOverall Test Accuracy: {}'.format(np.mean(test_acc_all)))
# Out:
# Getting Test Set Accuracy For 1115 Sentences.
# Test Observation #50
# Test Observation #100
# Test Observation #150
# Test Observation #200
# Test Observation #250
# Test Observation #300
# Test Observation #350
# Test Observation #400
# Test Observation #450
# Test Observation #500
# Test Observation #550
# Test Observation #600
# Test Observation #650
# Test Observation #700
# Test Observation #750
# Test Observation #800
# Test Observation #850
# Test Observation #900
# Test Observation #950
# Test Observation #1000
# Test Observation #1050
# Test Observation #1100
#
# Overall Test Accuracy: 0.8044843049327354

# %% [markdown]
# Let's look at the training accuracy over all the iterations.

# %%
# %matplotlib inline
# Plot training accuracy over time
plt.plot(range(len(train_acc_avg)), train_acc_avg, 'k-', label='Train Accuracy')
plt.title('Avg Training Acc Over Past 50 Iterations')
plt.xlabel('Iterations')
plt.ylabel('Training Accuracy')
plt.show()

# %% [markdown]
# It is worthwhile to mention the motivation of limiting the sentence (or text) size.  In this example we limited the text size to 25 words.  This is a common practice with bag of words because it limits the effect of text length on the prediction.  You can imagine that if we find a word, “meeting” for example, that is predictive of a text being ham (not spam), then a spam message might get through by putting in many occurrences of that word at the end.  In fact, this is a common problem with imbalanced target data.  Imbalanced data might occur in this situation, since spam may be hard to find and ham may be easy to find.  Because of this fact, our vocabulary that we create might be heavily skewed toward words represented in the ham part of our data (more ham means more words are represented in ham than spam).  If we allow unlimited length of texts, then spammers might take advantage of this and create very long texts, which have a higher probability of triggering non-spam word factors in our logistic model.
#
# In the next section, we attempt to tackle this problem in a better way using the frequency of word occurrence to determine the values of the word embeddings.

# %%
test complete; Gopal
